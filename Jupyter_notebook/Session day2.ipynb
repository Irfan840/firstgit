# %%
# body mass index (BMI)
# input weight
# hight
# BMI, ask yourself your hight
# weight
# calculate BMI
# print BMI (my name is..., my BMI is)

# %%
# weight on kg, hight in m and its square

# %%
height = input("what is your height ?")
# Out:
# what is your height ?1.74

# %%
height = float(height)

# %%
weight = input("what is your weight ?")
# Out:
# what is your weight ?68

# %%
weight = float(weight)

# %%
name = input("what is your name ?")
# Out:
# what is your name ?irfan

# %%
BMI = weight/height**2
BMI
# Out:
# 22.460034350640772

# %%
print("my name is", name, "and my bmi is", BMI)
# Out:
# my name is irfan and my bmi is 22.460034350640772

# %%
# Bar plot
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style= "ticks", color_codes = True)

# %%
titanic = sns.load_dataset("titanic")

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)

# %%
# scatter plot for countinous variables
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style= "ticks", color_codes = True)

# %%
titanic = sns.load_dataset("titanic")

# %%
g=sns.FacetGrid(titanic, row="sex", hue="alone")

# %%
g=(g.map(plt.scatter, "age", "fare",).add_legend())

# %%
plt.show()
